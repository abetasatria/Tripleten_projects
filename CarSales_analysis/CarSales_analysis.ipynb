# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
# # Reviewer's feedback v.1
#
# **Halo Ahmad**
#
# **Greetings from Chamdani**
#
# Terima kasih telah mengirimkan project kamu dengan ini kamu sudah memulai sebuah langkah yang luar biasa saat ini. Disini saya akan mereview proyek kamu ya.
#
# Saya akan memberikan beberapa komentar dan feedback seperti dibawah ini, **mohon jangan dipindah, dirubah, maupun dihapus ya :).**
#
# > Mohon diperhatikan bahwa apabila ada temuan atau kesalahan yang sama namun tidak ada komentar perbaikan disana, itu berarti kamu masih tetap harus memperbaikinya yaa.
#
# Komentar yang saya berikan akan muncul dalam warna hijau, kuning, atau pun merah seperti ini:
#
# </div>
#
# <div class="alert alert-success">
# <b>Chamdani's comment v.*</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>
#
# <div class="alert alert-warning">
# <b>Chamdani's comment v.*</b> <a class="tocSkip"></a>
#
# Ada beberapa catatan.
#
# </div>
#
# <div class="alert alert-danger">
# <b>Chamdani's comment v.*</b> <a class="tocSkip"></a>
#
# Perlu beberapa perbaikan.
#
# </div>
#
# <div class="alert alert-info">
# <b>Chamdani's info v.1</b> <a class="tocSkip"></a>
#
# Catatan umum:
# * Fungsi `print` tidak diperlukan untuk mencetak suatu nilai
# * Lebih baik tulis kode pada bagian akhir cell code untuk menampilkan output tanpa `print`
# * Perintah soal yang ada dalam tanda kurung siku `[...]` sebaiknya dihilangkan
# * Sangat disarankan untuk menggunakan cell markdown untuk memberikan deskripsi temuan atau kesimpulan.
# * Tidak disarankan menggunakan cell code untuk memberikan penjelasan / deskripsi.
# * Untuk menghindari galat pada notebook project kamu. Batasi jumlah output yang dikeluarkan setiap kode dengan batas max 10 baris data.
#
# </div>
#
# <div style="border:solid gray 5px; padding: 20px" class="alert alert-warning">
#
# **INGATLAH**
# * Project kamu tidak akan bisa diterima bila kamu masih memiliki feedback berwarna merah.
# * Kamu hanya memiliki 3 kali kesempatan iterasi submission disetiap projectnya
# * Kamu dapat memperbaiki dan menyelesaikan feedback **pertama** dari saya tidak lebih dari 1\*24 jam. *Untuk membantu saya mengetahui apakah ada kesulitan dari feedback project kamu*
# * Jika merasa kesulitan kamu dapat menuliskan responmu atas feedback saya menggunakan blok markdown warna biru yaa.
#
# Kamu dapat menjawab saya dengan menggunakan blok berwarna biru seperti ini
#
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px" class="alert alert-warning">
#
# # General feedback v.1 [Minor Improvement Needed]
#
# Terima kasih banyak telah mengirimkan proyek Anda!
#
# Secara keseluruhan, proyek Anda **SANGAT** mengesankan. Namun saya telah menemukan beberapa hal kecil ycang bisa menjadi saran perbaikan agar proyek kamu menjadi lebih baik lagi.
#
# Saya telah meninggalkan komentar yang dapat membantu Anda dalam hal tersebut. Hal ini tidak berarti bahwa Anda telah melakukan sesuatu yang salah. Hal ini hanya berisi beberapa saran tentang bagaimana pekerjaan Anda dapat kembangkan lebih lanjut. Anda masih memiliki kesempatan untuk memperbaikinya dan jangan lupa untuk kembali kepada saya setelah perbaikan anda selesai.
#
# <br>
# Jika ada sesuatu yang membuat Anda bingung atau tidak mengerti. Tolong, jangan ragu untuk menghubungi tim mentor atau instruktur kamu yaa
#
# kamu juga bisa menghubungi saya melalui reply feedback di notebook ini yaa
#
# **TETAP SEMANGAT!!**
#
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px" class="alert alert-success">
#
# # General feedback v.2 *Project Accepted*
#
# Terima kasih banyak telah mengirimkan perbaikan proyek Anda!
# <br>
#
# Secara keseluruhan, proyek Anda **SANGAT** mengesankan. Semoga apa yang kamu pelajari dalam project ini dapat membantu meningkatkan kemampuanmu. Pertahankan apa yang sudah bagus, dan tingkatkan apa yang menurutmu masih perlu ditingkatkan. Semoga berhasil pada project selanjutnya yaa :)
#
# **TETAP SEMANGAT!!**
#
# </div>

# %% [markdown]
# # **Faktor apakah yang menjual sebuah mobil?**
# Kamu adalah seorang analis di Crankshaft List. Ratusan iklan kendaraan gratis ditayangkan di situs web perusahaan setiap harinya. Nah, kamu ditugaskan untuk mempelajari data yang telah dikumpulkan selama beberapa tahun terakhir guna menentukan faktor-faktor yang memengaruhi harga sebuah kendaraan.

# %% [markdown]
# [Kami sudah memberikanmu beberapa komentar untuk digunakan sebagai panduanmu saat kamu menyelesaikan proyek ini. Namun, pastikan untuk menghapus semua komentar dalam tanda kurung sebelum mengirimkan proyekmu.]
# [Sebelum kamu menganalisis datamu, jelaskan tujuan dari proyek ini dan langkah-langkah yang akan kamu lakukan.]
# [Ingat bahwa mempelajari, mengubah, dan menganalisis data adalah proses yang dilakukan secara berulang. Kembali ke langkah sebelumnya untuk memperbaikinya supaya bisa lanjut ke langkah berikutnya adalah hal yang wajar, kok.]

# %% [markdown]
# <div class="alert alert-danger">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# **INGATLAH** pada setiap project, selain deskripsi proyek kamu juga harus memberikan pengantar proyek, daftar isi, dan tujuan proyek. Tepat seperti yang telah kami contohkan pada project pertama tentang Y-music.
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# **Project Crankshaft List**

# %% [raw]
# Konten:
# 1. Pendahuluan
# 2. Tujuan
# 3. Tahapan yang dilakukan:
#     Tahap 1. Pra-pemrosesan Data
#         -Memuat Data
#         -Mengeksplorasi Data Awal
#         -Kesimpulan dan Langkah-langkah Selanjutnya
#
#     Tahap 2. Memproses Data
#         -Mengatasi Nilai-Nilai yang Hiang (Jika Ada)
#         -Memperbaiki Tipe Data
#         -Memperbaiki Kualitas Data
#         -Memeriksa Data yang Sudah Bersih
#         -Mempelajari Parameter Inti
#         -Mempelajari dan Menangani Outlier
#         -Mempelajari Parameter Inti Tanpa Outlier
#         -Masa Berlaku Iklan
#         -Harga Rata-Rata Setiap Jenis Kendaraan
#         -Faktor-faktor yang mempengaruhi harga
#
# 4. Kesimpulan Umum

# %% [markdown]
# # ANALISIS PENJUALAN MOBIL DI SUATU WEBSITE JUAL BELI MOBIL

# %% [markdown]
# **1. PENDAHULUAN**
#
#    Crankshaft List adalah salah satu website untuk urusan jual beli mobil dari berbagai jenis, merk, dan type. Ratusan iklan kendaraan gratis ditayangkan di situs ini setiap harinya. Saya sebagai Data Analyst ditugaskan untuk mempelajari data yang telah dikumpulkan selama beberapa tahun terakhir guna menentukan faktor-faktor yang memengaruhi harga sebuah kendaraan. Melalui pendekatan analitis ini, kami berharap dapat memberikan informasi yang penting kepada pengguna situs kami, guna mendukung keputusan pembelian dan penjualan kendaraan yang lebih baik di situs jual beli mobil ini.

# %% [raw]
# 2. TUJUAN:
#     a. Menghitung rata-rata waktu iklan ditayangkan. Menentukan kapan waktu paling cepat dan paling lama iklan ditayangkan (listing).
#     b. Menentukan type mobil yang diiklankan paling banyak dan rata-rata harganya.
#     c. Menguji faktor-faktor yang mempengaruhi harga sebuah kendaraan antara lain:
#         - Usia mobil
#         - Kondisi Mobil
#         - Jumlah cylinder
#         - Jarak tempuh
#         - Warna mobil

# %% [raw]
# 3. TAHAPAN YANG DILAKUKAN
# Di sini kita akan melakukan analisa dataset pada /datasets/vehicles_us.csv.

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Pra-pemrosesan

# %%
# Muat semua library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ### Memuat Data

# %%
# Muat file data menjadi DataFrame
df = pd.read_csv('/datasets/vehicles_us.csv')

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ### Mengeksplorasi Data Awal

# %% [markdown]
# Dataset yang kamu miliki berisi kolom-kolom berikut:
#
# - `price`
# - `model_year`
# - `model`
# - `condition`
# - `cylinders`
# - `fuel` — gas, disel, dan lain-lain.
# - `odometer` — jarak tempuh kendaraan saat iklan ditayangkan
# - `transmission`
# - `paint_color`
# - `is_4wd` — apakah kendaraan memiliki penggerak 4 roda (tipe Boolean)- `date_posted` — tanggal iklan ditayangkan- `days_listed` — jumlah hari iklan ditayangkan hingga dihapus
# [Pahami kolom-kolomnya, lakukan eksplorasi data agar kamu terbiasa dengan data yang kamu miliki.]

# %%
# tampilkan informasi/rangkuman umum tentang DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %%
# tampilkan sampel data
df.sample(n=10)
# Out:
#        price  model_year                       model  condition  cylinders  \
# 28861    495      2004.0            hyundai santa fe       good        4.0
# 47788   2599      2016.0                  honda cr-v   like new        NaN
# 25330   3800      2001.0          chevrolet suburban       good        NaN
# 7321   13990      2006.0  chevrolet silverado 2500hd  excellent        8.0
# 27475  10500      2011.0             nissan frontier  excellent        NaN
# 27827   5350      2010.0                  ford focus       good        4.0
# 36652   4695      2004.0                honda accord  excellent        4.0
# 39789  15995      2008.0                  ford f-250       good       10.0
# 46887   2450      2004.0                 kia sorento       good        6.0
# 25278   3425      2010.0             subaru forester  excellent        4.0
#
#          fuel  odometer transmission    type paint_color  is_4wd date_posted  \
# ...

# %% [markdown]
# 1. Dari informasi umum terdapat 51.525 baris dan 13 kolom.
# 2. Terdapat 5 kolom yang mengandung nilai yang hilang yakni:model_year, cylinders, odometer, paint_color, dan is_4wd.

# %% [markdown]
# 3. Ada kolom dengan tipe data yang tidak sesuai yaitu kolom model_year, is_4wd, dan date_posted.
# 4. Kolom model_year harusnya tipe integer, kolom is_4wd harusnya integer, dan kolom date_posted harusnya tipe date.

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %%
#Menghitung persentase nilai yang hilang di setiap kolom
missing = df.isna().sum().to_frame()
missing = missing.rename(columns = {0: 'missing_values'})
missing['% of total'] = (missing['missing_values'] / df.shape[0]).round(2)
missing.sort_values(by= 'missing_values', ascending=False)
# Out:
#               missing_values  % of total
# is_4wd                 25953        0.50
# paint_color             9267        0.18
# odometer                7892        0.15
# cylinders               5260        0.10
# model_year              3619        0.07
# price                      0        0.00
# model                      0        0.00
# condition                  0        0.00
# fuel                       0        0.00
# transmission               0        0.00
# type                       0        0.00
# date_posted                0        0.00
# days_listed                0        0.00

# %% [markdown]
# 1. Terdapat nilai yang hilang di 5 kolom yakni : is_4wd, paint_color, odometer, cylinders, dan model_year
#
# 2. Kolom yang paling banyak memuat nilai yang hilang adalah kolom is_4wd sebanyak 50,36 %

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ### Kesimpulan dan Langkah-Langkah Selanjutnya

# %% [markdown]
# Kesimpulan Awal:
# 1. Ada 8 kolom yang terlihat normal dan ada 5 kolom yang tidak normal karena memuat nilai yang hilang yaitu is_4wd, paint_color, odometer, cylinders, dan model_year
# 2. Ada kolom dengan tipe data yang tidak sesuai yaitu kolom model_year dan date_posted
# 3. Langkah selanjutnya mengatasi nilai yang hilang serta mengubah tipe data menjadi tipe yang sesuai.

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Mengatasi Nilai-Nilai yang Hilang (Jika Ada)

# %% [markdown]
# **MENGATASI NILAI YANG HILANG DI KOLOM is_4wd**

# %%
# Memeriksa distribusi nilai di kolom is_4wd
df['is_4wd'].value_counts()
# Out:
# 1.0    25572
# Name: is_4wd, dtype: int64

# %%
df['is_4wd'] = df['is_4wd'].fillna(0)

# %%
# Memeriksa jumlah nilai yang hilang di kolom si_4wd --> hasilnya sudah 0
df.isnull().sum().sort_values(ascending=False) / len(df) * 100
# Out:
# paint_color     17.985444
# odometer        15.316836
# cylinders       10.208637
# model_year       7.023775
# price            0.000000
# model            0.000000
# condition        0.000000
# fuel             0.000000
# transmission     0.000000
# type             0.000000
# is_4wd           0.000000
# date_posted      0.000000
# days_listed      0.000000
# dtype: float64

# %% [markdown]
# Temuan data berdasarkan kolom is_4wd:
# 1. Pada kolom is_4wd terdapat nilai yang hilang sebanyak 25572.
# 2. Karena di kolom is 4wd hanya punya 2 value (1 dan 0), maka untuk value missing diberi angka 0.
# 3. Hasilnya adalah sudah tidak ada nilai hilang di kolom is_4wd.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **MENGATASI NILAI YANG HILANG DI KOLOM paint_color**

# %%
df['paint_color'].unique()
# Out:
# array([nan, 'white', 'red', 'black', 'blue', 'grey', 'silver', 'custom',
#        'orange', 'yellow', 'brown', 'green', 'purple'], dtype=object)

# %%
# Memeriksa jumlah nilai yang hilang di kolom paint_color
df['paint_color'].isnull().sum()
# Out:
# 9267

# %%
# Nilai yang hilang (nan) di kolom paint color diisi 'unknown' karena asumsi saya warna mobilnya tidak umum /jarang ditemui.
df['paint_color'] = df['paint_color'].fillna('unknown')

# %%
df['paint_color'].unique()
# Out:
# array(['unknown', 'white', 'red', 'black', 'blue', 'grey', 'silver',
#        'custom', 'orange', 'yellow', 'brown', 'green', 'purple'],
#       dtype=object)

# %% [markdown]
# nilai 'nan' sudah berganti ke 'unknown'.

# %%
# Memeriksa jumlah nilai yang hilang di kolom paint_color ==> hasilnya sudah 0
df.isnull().sum().sort_values(ascending=False) / len(df) * 100
# Out:
# odometer        15.316836
# cylinders       10.208637
# model_year       7.023775
# price            0.000000
# model            0.000000
# condition        0.000000
# fuel             0.000000
# transmission     0.000000
# type             0.000000
# paint_color      0.000000
# is_4wd           0.000000
# date_posted      0.000000
# days_listed      0.000000
# dtype: float64

# %% [markdown]
# Temuan berdasarkan data di kolom paint_color:
# 1. Di dalam kolom paint_color terdapat 13 jenis warna yakni: white, red, black, blue, grey, silver, orange, yellow, brown, green, purple, custom(warna yang disesuaikan dengan permintaan pembeli), dan nan (nilai yang hilang
# 2. Nilai yang hilang (nan) dalam kolom paint_color berjumlah 9267 baris.
# 3. Nilai yang hilang (nan) di kolom paint_color diisi 'unknown' karena asumsi saya warna mobilnya tidak umum /jarang ditemui.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ***MENGATASI NILAI YANG HILANG DI KOLOM odometer***

# %%
# Memeriksa jumlah nilai yang hilang di kolom odometer
df['odometer'].isnull().sum()
# Out:
# 7892

# %%
missing_odometer = df.loc[df['odometer'].isna()]

# %%
df =df.replace({None: np.nan})

# %%
# Memasukkan nilai median sebagai pengganti nilai yang hilang
median_odometer = df['odometer'].median()
median_odometer
# Out:
# 113000.0

# %%
odometer_by_condition = df.groupby('condition')['odometer'].transform('median')

# %%
df['odometer'].fillna(odometer_by_condition, inplace=True)

# %%
# Memeriksa jumlah nilai yang hilang di kolom odometer ==> hasilnya sudah 0
df.isnull().sum().sort_values(ascending=False) / len(df) * 100
# Out:
# cylinders       10.208637
# model_year       7.023775
# price            0.000000
# model            0.000000
# condition        0.000000
# fuel             0.000000
# odometer         0.000000
# transmission     0.000000
# type             0.000000
# paint_color      0.000000
# is_4wd           0.000000
# date_posted      0.000000
# days_listed      0.000000
# dtype: float64

# %% [markdown]
# Temuan berdasarkan data di kolom odometer:
# 1. Di dalam kolom odometer terdapat 7892 baris yang memuat nilai hilang.
# 2. tindakan yang saya lakukan adalah nilai yang hilang (nan) di kolom odometer diganti dengan nilai median odometer (113000)
# 3. Hasilnya adalah di kolom odometer sudah tidak ada nilai hilang.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **MENGATASI NILAI YANG HILANG DI KOLOM cylinders**

# %%
df['cylinders'].unique()
# Out:
# array([ 6.,  4.,  8., nan,  5., 10.,  3., 12.])

# %%
# Memeriksa jumlah nilai yang hilang di kolom cylinders
df['cylinders'].isnull().sum()
# Out:
# 5260

# %%
# Mengganti nilai yang hilang dengan median
median_cylinders = df['cylinders'].median()
median_cylinders
# Out:
# 6.0

# %%
cylinders_by_model = df.groupby('model')['cylinders'].transform('median')

df['cylinders'].fillna(cylinders_by_model, inplace=True)

# %%
# Memeriksa jumlah nilai yang hilang di kolom cylinders ==> hasilnya sudah 0
df.isnull().sum().sort_values(ascending=False) / len(df) * 100
# Out:
# model_year      7.023775
# price           0.000000
# model           0.000000
# condition       0.000000
# cylinders       0.000000
# fuel            0.000000
# odometer        0.000000
# transmission    0.000000
# type            0.000000
# paint_color     0.000000
# is_4wd          0.000000
# date_posted     0.000000
# days_listed     0.000000
# dtype: float64

# %% [markdown]
# Temuan berdasarkan data di kolom cylinders:
# 1. Nilai-nilai yang terkandung di kolom cylinders adalah:
#     3, 4, 5, 6, 8, 19, 12, nan (nilai hilang)
# 2. Di dalam kolom cylinders terdapat 5260 baris yang memuat nilai hilang.
# 2. Nilai yang hilang (nan) di kolom cylinders diganti dengan nilai median cylinder (6)
# 3. Hasilnya adalah di kolom cylinders sudah tidak ada nilai hilang.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **MENGATASI NILAI YANG HILANG DI KOLOM model_year**

# %%
# Memeriksa jumlah nilai yang hilang di kolommodel_year
df['model_year'].isnull().sum()
# Out:
# 3619

# %%
median_model_year = df['model_year'].median()
median_model_year
# Out:
# 2011.0

# %%
model_year_by_model = df.groupby('model')['model_year'].transform('median')

df['model_year'].fillna(model_year_by_model, inplace=True)

# %%
# Memeriksa jumlah nilai yang hilang di kolom model_year ==> hasilnya sudah 0
df.isnull().sum().sort_values(ascending=False) / len(df) * 100
# Out:
# price           0.0
# model_year      0.0
# model           0.0
# condition       0.0
# cylinders       0.0
# fuel            0.0
# odometer        0.0
# transmission    0.0
# type            0.0
# paint_color     0.0
# is_4wd          0.0
# date_posted     0.0
# days_listed     0.0
# dtype: float64

# %% [markdown]
# Temuan berdasarkan data di kolom model_year:
# 1. Di dalam kolom model_year terdapat 3619 baris yang memuat nilai hilang.
# 2. Nilai yang hilang di kolom model_year diganti dengan nilai median model_year (2011)
# 3. Hasilnya adalah di kolom model_year sudah tidak ada nilai hilang.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Memperbaiki Tipe Data

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# ***1.Mengubah Tipe Data di Kolom model_year***

# %%
df['model_year'].unique()
# Out:
# array([2011. , 2013. , 2003. , 2017. , 2014. , 2015. , 2012. , 2008. ,
#        2018. , 2009. , 2010. , 2007. , 2004. , 2005. , 2001. , 2006. ,
#        1966. , 1994. , 2019. , 2000. , 2016. , 1993. , 1999. , 2006.5,
#        1997. , 2002. , 1981. , 1995. , 1996. , 1975. , 1998. , 1985. ,
#        1977. , 1987. , 1974. , 1990. , 1992. , 1991. , 1972. , 1967. ,
#        1988. , 1969. , 1989. , 1978. , 1965. , 1979. , 1968. , 1986. ,
#        1980. , 1964. , 1963. , 1984. , 1982. , 2010.5, 1973. , 1970. ,
#        1955. , 1971. , 1976. , 1983. , 1954. , 1962. , 1948. , 1960. ,
#        1908. , 1961. , 1936. , 1949. , 1958. , 1929. ])

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %%
# Mengganti tipe data model_year ke integer
df['model_year'] = df['model_year'].astype('int16')

# %%
df['model_year'].unique()
# Tipenya sudah berubah menjadi integer
# Out:
# array([2011, 2013, 2003, 2017, 2014, 2015, 2012, 2008, 2018, 2009, 2010,
#        2007, 2004, 2005, 2001, 2006, 1966, 1994, 2019, 2000, 2016, 1993,
#        1999, 1997, 2002, 1981, 1995, 1996, 1975, 1998, 1985, 1977, 1987,
#        1974, 1990, 1992, 1991, 1972, 1967, 1988, 1969, 1989, 1978, 1965,
#        1979, 1968, 1986, 1980, 1964, 1963, 1984, 1982, 1973, 1970, 1955,
#        1971, 1976, 1983, 1954, 1962, 1948, 1960, 1908, 1961, 1936, 1949,
#        1958, 1929], dtype=int16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  int16
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(3), int16(1), int64(2), object(7)
# memory usage: 4.8+ MB

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# Temuan data berdasarkan kolom model_year:
# 1. Di dataframe awal, kolom model_year masih mengandung nilai desimal. Padahal seharusnya di kolom model_year harus bilangan bulat karena menunjukkan tahun.
# 2. Hasilnya adalah nilai di kolom model_year sudah berubah menjadi integer.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **2. Mengubah Tipe Data di Kolom cylinders**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  int16
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(3), int16(1), int64(2), object(7)
# memory usage: 4.8+ MB

# %%
df['cylinders'].unique()
# Out:
# array([ 6.,  4.,  8.,  5., 10.,  3., 12.])

# %%
# Mengganti tipe data cylinders ke integer
df['cylinders'] = df['cylinders'].astype('int16')

# %%
df['cylinders'].unique()
# Out:
# array([ 6,  4,  8,  5, 10,  3, 12], dtype=int16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  int16
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  int16
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(2), int16(2), int64(2), object(7)
# memory usage: 4.5+ MB

# %% [markdown]
# Temuan data berdasarkan kolom cylinders:
# 1. Di dataframe awal, kolom cylinders masih mengandung nilai desimal. Padahal seharusnya di kolom cylinders harus bilangan bulat karena menunjukkan jumlah cylinders.
# 2. Hasilnya adalah nilai di kolom cylinders sudah berubah menjadi integer.

# %% [markdown]
# **3. Mengubah Tipe Data di Kolom is_4wd**

# %%
df['is_4wd'].unique()
# Out:
# array([1., 0.])

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %%
# Mengganti tipe data model_year ke integer
df['is_4wd'] = df['is_4wd'].astype('boolean')

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %%
df['is_4wd'].unique()
# Tipenya sudah berubah menjadi boolean
# Out:
# <BooleanArray>
# [True, False]
# Length: 2, dtype: boolean

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# Temuan berdasarkan kolom is_4wd:
# 1. Nilai dalam kolom is_4wd diubah ke type boolean karena hanya mengandung dua nilai 1 dan 0.
# 2. Nilai 1 berarti True dan nilai 0 berarti False.
# 3. Nilai True berarti mobil tersebut bertipe 4wd dan nilai False berarti mobil tersebut bukan tipe 4wd.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# **4. Mengubah Tipe Data di Kolom price**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  int16
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  int16
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  boolean
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: boolean(1), float64(1), int16(2), int64(2), object(7)
# memory usage: 4.2+ MB

# %%
df['price'].unique()
# Out:
# array([ 9400, 25500,  5500, ...,  3636,  9249,  7455])

# %%
df['price'] = df['price'].astype('float64')

# %%
df['price'].unique()
# Out:
# array([ 9400., 25500.,  5500., ...,  3636.,  9249.,  7455.])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  float64
#  1   model_year    51525 non-null  int16
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  int16
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  boolean
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: boolean(1), float64(2), int16(2), int64(1), object(7)
# memory usage: 4.2+ MB

# %% [markdown]
# Temuan berdasarkan kolom price:
# 1. Nilai dalam kolom price diubah ke type float karena mungkin mengandung pecahan.
# 2. Hasilnya adalah nilai di kolom price sudah berubah menjadi float.

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ***5. Mengubah Tipe Data di Kolom date_posted***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  float64
#  1   model_year    51525 non-null  int16
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  int16
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  boolean
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: boolean(1), float64(2), int16(2), int64(1), object(7)
# memory usage: 4.2+ MB

# %%
df['date_posted']
# Out:
# 0        2018-06-23
# 1        2018-10-19
# 2        2019-02-07
# 3        2019-03-22
# 4        2019-04-02
#             ...
# 51520    2018-10-03
# 51521    2018-11-14
# 51522    2018-11-15
# 51523    2018-07-02
# 51524    2018-06-05
# Name: date_posted, Length: 51525, dtype: object

# %%
# Mengganti tipe data date posted ke datetime
df['date_posted'] = pd.to_datetime(df['date_posted'])

# %%
df['date_posted']
# Tipenya sudah berubah menjadi datetime
# Out:
# 0       2018-06-23
# 1       2018-10-19
# 2       2019-02-07
# 3       2019-03-22
# 4       2019-04-02
#            ...
# 51520   2018-10-03
# 51521   2018-11-14
# 51522   2018-11-15
# 51523   2018-07-02
# 51524   2018-06-05
# Name: date_posted, Length: 51525, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  float64
#  1   model_year    51525 non-null  int16
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  int16
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  boolean
#  11  date_posted   51525 non-null  datetime64[ns]
#  12  days_listed   51525 non-null  int64
# dtypes: boolean(1), datetime64[ns](1), float64(2), int16(2), int64(1), object(6)
# memory usage: 4.2+ MB

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# Temuan berdasarkan data di kolom date_posted:
# 1. Di dataframe awal, nilai di kolom date_posted tipenya adalah string.
# 2. Nilai di kolom date_posted diubah menjadi tipe datetime karena menunjukkan tanggal.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Memperbaiki Kualitas Data

# %%
# Tambahkan nilai waktu dan tanggal pada saat iklan ditayangkan
df['day_posted'] = df['date_posted'].dt.day
df['month_posted'] = df['date_posted'].dt.month
df['year_posted'] = df['date_posted'].dt.year

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %%
# Tambahkan usia kendaraan saat iklan ditayangkan
df['car_age'] = (df['year_posted'] - df['model_year']).astype(int) + 1

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Siap kak
#
# <div/>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %%
# Tambahkan jarak tempuh rata-rata kendaraan per tahun 
df['odo_per_year'] = df['odometer'] / df['car_age']

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %%
# Mungkin membantu untuk mengganti nilai pada kolom 'condition' dengan sesuatu yang bisa dimanipulasi lebih mudah
def condition_categorizing(value):
    if value == 'salvage':
        return 0
    elif value == 'fair':
        return 1
    elif value == 'good':
        return 2
    elif value == 'excellent':
        return 3
    elif value == 'like new':
        return 4
    else:
        return 5

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %%
df['condition_category'] = df['condition'].apply(condition_categorizing)

# %%
# Memeriksa kolom baru 'condition_category'
df.loc[:, ['condition', 'condition_category']].sample(n=15)
# Out:
#        condition  condition_category
# 19155  excellent                   3
# 31528       good                   2
# 21016       good                   2
# 861    excellent                   3
# 9906    like new                   4
# 40585       good                   2
# 1976   excellent                   3
# 50885       good                   2
# 51211       good                   2
# 31645       good                   2
# 34806  excellent                   3
# 25988  excellent                   3
# 43567       good                   2
# 27459  excellent                   3
# 16552  excellent                   3

# %% [markdown]
# 1. Dari data date_posted dipecah menjadi 3 kolom baru yakni day_posted, month_posted, dan year_posted.
# 2. Dari nilai year_posted dikurangi nilai dari model_year, didapatkan nilai usia mobil ketika ditayangkan (car_age).
# 3. Dari nilai odometer dibagi dengan usia mobil, didapatkan nilai rata-rata jarak tempuh mobil per tahun (odo_per_year).
# 4. Untuk kolom condition, keterangan kondisi mobil diganti ke angka:
#     0 artinya salvage, 1 artinya fair, 2 artinya good, 3 artinya excellent, 4 artinya like new, 5 artinya new.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Memeriksa Data yang Sudah Bersih

# %%
# tampilkan informasi/rangkuman umum tentang DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   price               51525 non-null  float64
#  1   model_year          51525 non-null  int16
#  2   model               51525 non-null  object
#  3   condition           51525 non-null  object
#  4   cylinders           51525 non-null  int16
#  5   fuel                51525 non-null  object
#  6   odometer            51525 non-null  float64
#  7   transmission        51525 non-null  object
#  8   type                51525 non-null  object
#  9   paint_color         51525 non-null  object
#  10  is_4wd              51525 non-null  boolean
#  11  date_posted         51525 non-null  datetime64[ns]
#  12  days_listed         51525 non-null  int64
#  13  day_posted          51525 non-null  int64
#  14  month_posted        51525 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %%
# tampilkan sampel data 
df.sample(n=10)
# Out:
#          price  model_year                       model  condition  cylinders  \
# 16536   3901.0        2001                honda accord  excellent          4
# 40033   1896.0        2008                 ford fusion       good          6
# 23899  10495.0        2014                 ford escape  excellent          4
# 15828  10800.0        2014              hyundai sonata       good          4
# 39864  39988.0        2015  chevrolet silverado 2500hd   like new          8
# 5774    4900.0        2009              toyota corolla       good          4
# 47171    500.0        2014                  ford f-150       good          4
# 51272   6650.0        2010               nissan maxima   like new          6
# 15369  14995.0        2011               ford explorer  excellent          6
# 40892   2995.0        2004                  ford focus  excellent          4
#
#          fuel  odometer transmission   type paint_color  is_4wd date_posted  \
# ...

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **Rangkuman umum terhadap dataframe yang baru**:
# 1. Jumlah kolom bertambah menjadi 19 kolom
# 2. Sudah tidak ada nilai yang hilang
# 3. Tipe data masing-masing kolom sudah sesuai
# 4. Dataframe sudah bisa diproses selanjutnya

# %% [markdown]
# ## Mempelajari Parameter Inti
#
# - Parameternya adalah:
# - Harga
# - Usia kendaraan ketika iklan ditayangkan
# - Jarak tempuh
# - Jumlah silinder
# - Kondisi

# %% [markdown]
# **-MEMERIKSA KOLOM price**

# %%
def histogram(dataframe, column, binwidth=None):
    plt.figure(figsize=(16, 8))
    plt.title(f'Histogram dari kolom {column}')
    sns.histplot(dataframe[column], binwidth=binwidth)
    plt.show()

# %%
df['price'].describe()
# Out:
# count     51525.000000
# mean      12132.464920
# std       10040.803015
# min           1.000000
# 25%        5000.000000
# 50%        9000.000000
# 75%       16839.000000
# max      375000.000000
# Name: price, dtype: float64

# %%
histogram(dataframe=df, column='price')

# %%
sns.boxplot(y=df['price'])
plt.show()

# %% [markdown]
# Temuan data (findings) berdasarkan diagram kolom price:
# 1. Harga mobil tersebar pada range harga 0 - 50000
# 2. Ada data outlier yang mencapai 350000
# 3. Rata-rata harga mobil adalah 12132,46
# 4. 50% mobil dijual dibawah harga 9000
# 5. Batas atas outlier harga mobil adalah sekitar 45000

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **-MEMERIKSA KOLOM car_age**

# %%
df['car_age'].describe()
# Out:
# count    51525.000000
# mean         9.513906
# std          6.112976
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         13.000000
# max        111.000000
# Name: car_age, dtype: float64

# %%
histogram(dataframe=df, column='car_age')

# %%
sns.boxplot(y=df['car_age'])
plt.show()

# %% [markdown]
# Temuan data (findings) berdasarkan diagram kolom car_age:
#
# 1. Usia mobil pada saat iklan ditayangkan tersebar pada range usia 0 - 20 tahun
# 2. Ada data outlier usia mobil mencapai 111 tahun
# 3. Rata-rata usia mobil adalah 9,5 tahun
# 4. Batas atas outlier usia mobil adalah 25 tahun

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **-MEMERIKSA KOLOM odo_per_year**

# %%
df['odo_per_year'].describe()
# Out:
# count     51525.000000
# mean      15378.482765
# std       11808.757090
# min           0.000000
# 25%        9363.636364
# 50%       13036.181818
# 75%       18222.222222
# max      373200.000000
# Name: odo_per_year, dtype: float64

# %%
histogram(dataframe=df, column='odo_per_year')

# %%
sns.boxplot(y=df['odo_per_year'])
plt.show()

# %% [markdown]
# Temuan data (findings) berdasarkan diagram kolom odo_per_year:
#
# 1. Nilai rata-rata jarak tempuh mobil per tahun pada saat iklan ditayangkan tersebar pada range 0 - 50000 km/tahun
# 2. Ada data outlier odo per year mobil mencapai 373200 km/tahun
# 3. Rata-rata odo_per_year mobil adalah 15378.48 km/tahun
# 4. 50% odometer mobil masih di bawah 13036.18 km/tahun

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **-MEMERIKSA KOLOM cylinders**

# %%
df['cylinders'].value_counts()
# Out:
# 8     17712
# 6     17435
# 4     15499
# 10      549
# 5       294
# 3        34
# 12        2
# Name: cylinders, dtype: int64

# %%
# Persentase jenis cylinders mobil yang diiklankan
df['cylinders'].value_counts() / len(df) * 100
# Out:
# 8     34.375546
# 6     33.837943
# 4     30.080543
# 10     1.065502
# 5      0.570597
# 3      0.065987
# 12     0.003882
# Name: cylinders, dtype: float64

# %%
# Karena nilai dalam kolom cylinders tidak banyak, maka kita bisa menggunakan diagram batang (bar)
sns.countplot(data=df, x='cylinders')
plt.show()

# %%
sns.boxplot(y=df['cylinders'])
plt.show()

# %% [markdown]
# Temuan data (findings) berdasarkan diagram kolom cylinders:
#
# 1. Mobil yang paling banyak diiklankan adalah mobil dengan jumlah cylinder 8, 6, dan 4 (mencapai 97 %)
# 2. 3 % sisanya adalah mobil dengan jumlah cylinder 3,5,10, dan 12.
# 3. Dari diagram boxplot, jumlah mobil yang diiklankan tersebar diantara 3 jenis cylinder yakni 4, 6, dan 8.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **-MEMERIKSA KOLOM condition**

# %%
df['condition'].value_counts()
# Out:
# excellent    24773
# good         20145
# like new      4742
# fair          1607
# new            143
# salvage        115
# Name: condition, dtype: int64

# %%
# Persentase kondisi mobil yang diiklankan
df['condition'].value_counts() / len(df) * 100
# Out:
# excellent    48.079573
# good         39.097525
# like new      9.203299
# fair          3.118874
# new           0.277535
# salvage       0.223193
# Name: condition, dtype: float64

# %%
# Karena nilai dalam kolom condition tidak banyak, maka kita bisa menggunakan diagram batang (bar)
sns.countplot(data=df, x='condition')
plt.show()

# %%
sns.boxplot(y=df['condition_category'])
plt.show()

# %% [markdown]
# Temuan data (findings) berdasarkan diagram kolom condition:
#
# 1. Mobil yang paling banyak diiklankan adalah mobil dengan kondisi excellent yakni sebanyak 48,07 % dan mobil dengan kondisi good sebanyak 39,09 %.
# 2. Mobil baru (new) dan rongsokan (salvage) sangat sedikit diiklankan, hanya sebanyak 0,2 %.
# 3. Dari diagram boxplot, kondisi 1 (fair) adalah batas bawah outlier jadi minimal kondisi mobil yang akan diiklankan adalah mobil dengan kondisi fair (sedang). Sedangkan kondisi 4 (like new) adalah batas atas outlier kondisi mobil yang akan diiklankan.
# 4. Untuk mobil new (baru) biasanya dijual langsung di dealer.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Mempelajari dan Menangani Outlier

# %% [markdown]
# -Berdasarkan diagram di atas, kolom yang memiliki nilai outlier adalah kolom price, car_age, dan odo_per_year.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Chamdani's info v.1</b> <a class="tocSkip"></a>
#
# Outlier merupakan nilai data yang tak biasa dari suatu kolom. Dia terkadang bisa lebih kecil atau lebih besar dari kecenderungan nilai dari kolom tersebut. Lihatlah histogram yang kamu buat diatas, range nilai pada sumbu x terlihat sangat jauh. Hal ini memperlihatkan bahwa kemungkinan percilan atau outlier berada pada rentang nilai diatas nilai Q3 dan upper limit dari boxplot. Dan itu terbukti dalam boxplot yang kamu tampilkan diatas.
#
# **Perhatikan gambaran berikut**
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# </div>

# %% [markdown]
# Membuat sebuah fungsi untuk menghitung dan mengembalikan nilai `lower_whisker` dan `upper_whisker` dari kolom yang mengandung nilai outlier yakni kolom 'price', 'car_age, dan 'odo_per_year'.

# %%
def upper_lower_whisker(series):
    Q1  = series.quantile(0.25)
    Q3  = series.quantile(0.75)
    
    IQR = Q3 - Q1
    
    lower_whisker = IQR - (1.5 * IQR)
    upper_whisker = IQR + (1.5 * IQR)
    
    return lower_whisker, upper_whisker

# %%
def outlier_cleansing(dataframe, column):
    
    lower, upper = upper_lower_whisker(dataframe[column])
    print(f'lower values : {lower}')
    print(f'upper values : {upper}')
    
    plt.title('Before cleaning outlier!')
    sns.boxplot(data=dataframe, x=column)
    plt.show()

    dataframe = dataframe[(dataframe[column] > lower) & (dataframe[column] < upper)]

    lower_check, upper_check = upper_lower_whisker(dataframe[column])
    print(f'lower_check values : {lower}')
    print(f'upper_check values : {upper}')

    plt.title('After cleaning outlier!')
    sns.boxplot(data=dataframe, x=column)
    plt.show()
    
    return dataframe

    if lower == lower_check or upper == upper_check:
        print(f'\n====== [FINISHED] outlier in [{column}] column has been clear! ====== \n')
        return dataframe

    else:
        print(f'\n------ [RE-START] cleaning outlier in {column} column ------ \n')
        dataframe = outlier_cleansing(dataframe=dataframe, column=column)
        return dataframe

# %%
# Menyimpan data tanpa outlier dalam dataframe baru
df_final = df.copy()
list_of_selected_column = ['price', 'odo_per_year', 'car_age']

for column in list_of_selected_column:
    print(f'\n====== [START] cleaning outlier in {column} column ====== \n')
    df_final = outlier_cleansing(dataframe=df_final, column=column)
# Out:
# ====== [START] cleaning outlier in price column ======
#
# lower values : -5919.5
# upper values : 29597.5
# lower_check values : -5919.5
# upper_check values : 29597.5
# ====== [START] cleaning outlier in odo_per_year column ======
#
# lower values : -4255.9375
# upper values : 21279.6875
# lower_check values : -4255.9375
# upper_check values : 21279.6875
# ====== [START] cleaning outlier in car_age column ======
#
# lower values : -3.5
# upper values : 17.5
# lower_check values : -3.5
# upper_check values : 17.5

# %% [markdown]
# Dari diagram boxplot diatas dapat kita simpulkan bahwa:
# 1. Batas atas outlier harga mobil adalah 29597.5
# 2. Batas atas outlier rata-rata jarak tempuh mobil per tahun adalah21279.68 km
# 3. Batas atas outlier usia mobil adalah 17.5 tahun

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Chamdani's info v.1</b> <a class="tocSkip"></a>
#
# Agar lebih optimal kamu bisa membuat sebuah fungsi untuk menghitung dan mengembalikan nilai `lower_whisker` dan `upper_whisker` dari kolom yang kamu kehendaki. Fungsi ini akan membantumu mengoptimalkan kode untuk penanganan outlier menjadi lebih singkat.
#
# **Hint :**
#
# ```python
# # Cell code 1
# def upper_lower_whisker(series):
#     Q1  = series.quantile(...)
#     Q3  = series.quantile(...)
#
#     IQR = ... - ...
#
#     lower_whisker = ... - (... * ...)
#     upper_whisker = ... + (... * ...)
#
#     return lower_whisker, upper_whisker
#
#
# ```
# ```python
# # Cell code 2
# def outlier_cleansing(dataframe, column):
#
#     lower, upper = upper_lower_whisker(dataframe[...])
#     print(f'lower values : {...}')
#     print(f'upper values : {...}')
#
#     plt.title('Before cleaning outlier!')
#     sns.boxplot(data=..., x=...)
#     plt.show()
#
#     dataframe = dataframe[(dataframe[...] > ...) & (dataframe[...] < ...)]
#
#     lower_check, upper_check = upper_lower_whisker(dataframe[...])
#     print(f'lower_check values : {...}')
#     print(f'upper_check values : {...}')
#
#     plt.title('After cleaning outlier!')
#     sns.boxplot(data=..., x=...)
#     plt.show()
#
#     if lower == ... or ... == upper_check:
#         print(f'\n====== [FINISHED] outlier in [{column}] column has been clear! ====== \n')
#         return dataframe
#
#     else:
#         print(f'\n------ [RE-START] cleaning outlier in {column} column ------ \n')
#         dataframe = outlier_cleansing(dataframe=..., column=...)
#         return dataframe
#
# ```
# ```python
# # Cell code 3
#
# df_final = data.copy()
# list_of_selected_column = ['condition', 'price', 'avg_mileage', 'lifetime', 'cylinders']
#
# for column in list_of_selected_column:
#     print(f'\n====== [START] cleaning outlier in {column} column ====== \n')
#     df_final = outlier_cleansing(dataframe=..., column=...)
# ```
#
# > ### Jangan lupa untuk deskripsikan seluruh temuanmu juga yaa
# </div>

# %% [markdown]
# ## Mempelajari Parameter Inti Tanpa Outlier

# %% [markdown]
# ***1. DIAGRAM KOLOM price***

# %%
# Grafik Histogram kolom price DENGAN OUTLIER
histogram(dataframe=df, column='price', binwidth=1000)

# %%
df_final['price'].describe()
# Out:
# count    36666.000000
# mean     10448.944935
# std       6888.187627
# min          1.000000
# 25%       4999.000000
# 50%       8500.000000
# 75%      14900.000000
# max      29588.000000
# Name: price, dtype: float64

# %%
# Grafik Histogram kolom price TANPA OUTLIER
histogram(dataframe=df_final, column='price', binwidth=1000)

# %% [markdown]
# Temuan data dari diagram price tanpa outlier:
# 1. Rata-rata harga mobil turun dari 12132.46 menjadi 10448.94
# 2. 50% mobil dijual di bawah harga 8500
# 3. Harga mobil tertinggi adalah 29588

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ***2. DIAGRAM KOLOM car_age***

# %%
# Grafik Histogram kolom car_age DENGAN OUTLIER
histogram(dataframe=df, column='car_age', binwidth=3)

# %%
df_final['car_age'].describe()
# Out:
# count    36666.000000
# mean         9.421644
# std          3.970405
# min          1.000000
# 25%          6.000000
# 50%          9.000000
# 75%         12.000000
# max         17.000000
# Name: car_age, dtype: float64

# %%
# Grafik Histogram kolom car_age TANPA OUTLIER
histogram(dataframe=df_final, column='car_age', binwidth=1)

# %% [markdown]
# Temuan data dari diagram car_age tanpa outlier:
#
# 1. Rata-rata usia mobil turun dari 9.51 tahun menjadi 9.42 tahun
# 2. 50% usia mobil yang diiklankan di bawah 9 tahun
# 3. Usia mobil tertinggi adalah 17 tahun

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ***3. DIAGRAM KOLOM odo_per_year***

# %%
# Grafik Histogram kolom odo_per_year DENGAN OUTLIER
histogram(dataframe=df, column='odo_per_year', binwidth=10000)

# %%
df_final['odo_per_year'].describe()
# Out:
# count    36666.000000
# mean     12361.192368
# std       4545.853119
# min          0.000000
# 25%       9377.625000
# 50%      12420.812500
# 75%      15666.666667
# max      21278.000000
# Name: odo_per_year, dtype: float64

# %%
# Grafik Histogram kolom odo_per_year TANPA OUTLIER
histogram(dataframe=df_final, column='odo_per_year', binwidth=1000)

# %% [markdown]
# Temuan data dari diagram odo_per_year tanpa outlier:
#
# 1. Rata-rata jarak tempuh mobil yang diiklankan turun dari 15378.48 km/tahun menjadi 12361.19 km/tahun
# 2. 50% jarak tempuh mobil yang diiklankan berada di bawah 12420.81 km/tahun
# 3. Jarak tempuh mobil tertinggi adalah 21278 km/tahun

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Masa Berlaku Iklan

# %%
df_final['days_listed'].describe()
# Out:
# count    36666.000000
# mean        39.603120
# std         28.183237
# min          0.000000
# 25%         19.000000
# 50%         33.000000
# 75%         53.000000
# max        271.000000
# Name: days_listed, dtype: float64

# %%
histogram(dataframe=df_final, column='days_listed', binwidth=20)

# %%
sns.boxplot(y=df_final['days_listed'])
plt.show()

# %% [markdown]
# Berdasarkan temuan dalam diagram kolom days_listed:
# 1. Rata-rata iklan ditayangkan selama 39.6 hari.
# 2. paling cepat iklan mobil ditayangkan kurang dari sehari. Artinya mobil tersebut terjual di hari yang sama ketika iklan mobil itu ditayangkan.
# 3. Iklan mobil yang paling lama ditayangkan adalah selama 271 hari (9 bulanan).
# 4. Nilai batas outier adalah 100 hari artinya iklan mobil dikatakan sangat lama jika sudah ditayangkan lebih dari 100 hari.

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Harga Rata-Rata Setiap Jenis Kendaraan

# %%
top_type = df_final.groupby(['type']).agg({'price':'mean', 'model':'count'}).rename(columns=
                        {'price':'avg_price', 'model':'count_type'}).sort_values(by='count_type', ascending=False)
top_type
# Out:
#                 avg_price  count_type
# type
# sedan         6724.488057        9671
# SUV           9913.499252        9364
# truck        14154.502445        7772
# pickup       14014.100023        4289
# coupe        13376.489937        1590
# wagon         8861.623165        1226
# mini-van      7567.596112         926
# hatchback     6585.420307         847
# van           7766.716553         441
# convertible  13849.433790         219
# other         9601.600000         180
# offroad      15277.243902         123
# bus          19959.166667          18

# %%
top_type.plot(kind='bar', grid=True, figsize=(12, 6),)
plt.ylabel('Average Price per Type')
# Out:
# Text(0, 0.5, 'Average Price per Type')

# %% [markdown]
# Temuan data berdasarkan type mobil
# 1. Type mobil yang paling banyak diiklankan adalah type Sedan (9671 iklan) dan SUV (9364 iklan).
# 2. Type mobil yang paling sedikit diiklankan adalah type Offroad dan Bus.
# 3. Rata-rata harga mobil SUV lebih tinggi daripada rata-rata harga mobil Sedan.

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Faktor-faktor yang Mempengaruhi Harga jual Mobil

# %% [markdown]
# **[Type mobil yang paling banyak diiklankan adalah type Sedan dan SUV]**

# %% [markdown]
# **A. Type Sedan**

# %%
data_sedan = df_final[df_final['type']=='sedan'].reset_index(drop=True)
data_sedan.head()
# Out:
#      price  model_year           model  condition  cylinders fuel  odometer  \
# 0   5500.0        2013  hyundai sonata   like new          4  gas  110000.0
# 1  14990.0        2014    chrysler 300  excellent          6  gas   57954.0
# 2  12990.0        2015    toyota camry  excellent          4  gas   79212.0
# 3   8990.0        2012    honda accord  excellent          4  gas  111142.0
# 4  16500.0        2018  hyundai sonata  excellent          4  gas   22104.0
#
#   transmission   type paint_color  is_4wd date_posted  days_listed  \
# 0    automatic  sedan         red   False  2019-02-07           79
# 1    automatic  sedan       black    True  2018-06-20           15
# 2    automatic  sedan       white   False  2018-12-27           73
# 3    automatic  sedan        grey   False  2019-03-28           29
# 4    automatic  sedan      silver   False  2019-01-14           29
#
#    day_posted  month_posted  year_posted  car_age  odo_per_year  \
# ...

# %%
data_sedan.corr()['price'].sort_values()
# Out:
# car_age              -0.609143
# odometer             -0.543513
# month_posted         -0.050802
# cylinders            -0.046958
# odo_per_year         -0.020852
# days_listed          -0.004915
# day_posted           -0.000052
# is_4wd                0.032466
# year_posted           0.050141
# condition_category    0.282839
# model_year            0.612896
# price                 1.000000
# Name: price, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **-Korelasi Antara Harga dengan Usia Mobil**

# %%
# Diagram korelasi antara harga dengan usia mobil
sns.scatterplot(data=data_sedan, x='car_age', y='price')
# Out:
# <AxesSubplot:xlabel='car_age', ylabel='price'>

# %% [markdown]
# Berdasarkan diagram di atas, mobil sedan yang usianya rendah, harganya lebih tinggi. Semakin bertambah usia mobil, harganya semakin turun.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **-Korelasi Antara Harga dengan Rata-rata Jarak Tempuh Mobil**

# %%
# Diagram korelasi antara harga dengan rata-rata jarak tempuh mobil
sns.scatterplot(data=data_sedan, x='odo_per_year', y='price')
# Out:
# <AxesSubplot:xlabel='odo_per_year', ylabel='price'>

# %% [markdown]
# Berdasarkan diagram di atas, rata-rata jarak tempuh mobil sedan tidak berpengaruh terhadap harga. Walaupun rata-rata jarak tempuhnya naik, harganya tidak naik.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **-Korelasi Antara Harga dengan Kondisi Mobil**

# %%
data_sedan['condition'].value_counts()
# Out:
# excellent    4983
# good         3389
# like new     1036
# fair          200
# new            37
# salvage        26
# Name: condition, dtype: int64

# %%
# Data yang di bawah 50 tidak dihitung
# Data new dan salvage tidak dihitung

top4_condition = list(data_sedan['condition'].value_counts()[:-2].index)
top4_condition
# Out:
# ['excellent', 'good', 'like new', 'fair']

# %%
top4_condition_sedan = data_sedan[data_sedan['condition'].isin(top4_condition)].reset_index(drop=True)

# %%
# Diagram korelasi antara harga dengan kondisi mobil
sns.boxplot(data=top4_condition_sedan, x='condition', y='price')
plt.title('Correlation between Price and Condition')
# Out:
# Text(0.5, 1.0, 'Correlation between Price and Condition')

# %% [markdown]
# 1. Dari diagram boxplot diatas, dapat kita ketahui bahwa kisaran harga mobil sedan dengan kondisi 'like new' lebih tinggi dibandingkan dengan kondisi yang lain dengan batas atas harganya mencapai 22000.
# 2. Harga mobil sedan paling rendah adalah harga mobil dengan kondisi 'fair' (sedang) dengan batas atas harganya mencapai 5000.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **-Korelasi Antara Harga dengan Type Transmisi Mobil**

# %%
data_sedan['transmission'].value_counts()
# Out:
# automatic    9104
# manual        469
# other          98
# Name: transmission, dtype: int64

# %%
# Diagram korelasi antara harga dengan transmisi mobil
sns.boxplot(data=data_sedan, x='transmission', y='price')
plt.title('Correlation between Price and Transmission')
# Out:
# Text(0.5, 1.0, 'Correlation between Price and Transmission')

# %% [markdown]
# 1. Dari diagram boxplot di atas dapat kita ketahui bahwa mobil sedan dengan tipe transmisi 'automatic' memiliki kisaran harga yang lebih tinggi dibandingkan tipe transmisi yang lain dengan batas atas harganya mencapai 17000.
# 2. Mobil sedan dengan tipe transmisi manual memiliki kisaran harga paling rendah dengan batas atas harganya mencapai 14000.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **-Korelasi Antara Harga dengan Warna Mobil**

# %%
data_sedan['paint_color'].value_counts()
# Out:
# unknown    1735
# silver     1624
# black      1401
# grey       1297
# white      1185
# blue       1013
# red         786
# custom      235
# brown       200
# green       149
# purple       23
# yellow       17
# orange        6
# Name: paint_color, dtype: int64

# %%
# Data yang di bawah 50 tidak dihitung
# Data warna purple, yellow, dan orange tidak dihitung
top10_color = list(data_sedan['paint_color'].value_counts()[:-3].index)
top10_color
# Out:
# ['unknown',
#  'silver',
#  'black',
#  'grey',
#  'white',
#  'blue',
#  'red',
#  'custom',
#  'brown',
#  'green']

# %%
top10_color_sedan = data_sedan[data_sedan['paint_color'].isin(top10_color)].reset_index(drop=True)

# %%
# Diagram korelasi antara harga dengan warna mobil
sns.boxplot(data=top10_color_sedan, x='paint_color', y='price')
plt.title('Correlation between Price and Color')
plt.figure(figsize=(12,6))

# %% [markdown]
# 1. Dari diagram boxplot di atas dapat kita ketahui bahwa mobil sedan dengan warna 'black' (hitam) memiliki kisaran harga paling tinggi dengan batas atas harganya mencapai 19000.
# 2. Mobil sedan dengan kisaran harga paling rendah adalah mobil berwarna 'green' (hijau) dengan batas atas harganya mencapai 12000.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **B.Type SUV**

# %%
data_suv = df_final[df_final['type']=='SUV'].reset_index(drop=True)
data_suv.head()
# Out:
#      price  model_year        model  condition  cylinders fuel  odometer  \
# 0   9400.0        2011       bmw x5       good          6  gas  145000.0
# 1  15990.0        2013  honda pilot  excellent          6  gas  109473.0
# 2  11500.0        2012  kia sorento  excellent          4  gas  104174.0
# 3   9200.0        2008  honda pilot  excellent          6  gas  147191.0
# 4  12990.0        2009    gmc yukon  excellent          8  gas  132285.0
#
#   transmission type paint_color  is_4wd date_posted  days_listed  day_posted  \
# 0    automatic  SUV     unknown    True  2018-06-23           19          23
# 1    automatic  SUV       black    True  2019-01-07           68           7
# 2    automatic  SUV     unknown    True  2018-07-16           19          16
# 3    automatic  SUV        blue    True  2019-02-15           17          15
# 4    automatic  SUV       black    True  2019-01-31           24          31
#
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **-Korelasi Antara Harga dengan Usia Mobil**

# %%
# Diagram korelasi antara harga dengan usia mobil
sns.scatterplot(data=data_suv, x='car_age', y='price')
# Out:
# <AxesSubplot:xlabel='car_age', ylabel='price'>

# %% [markdown]
# Berdasarkan diagram di atas, mobil SUV yang usianya rendah, harganya lebih tinggi. Semakin bertambah usia mobil, harganya semakin turun.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **-Korelasi Antara Harga dengan Jarak Tempuh Mobil**

# %%
# Diagram korelasi antara harga dengan rata-rata jarak tempuh mobil
sns.scatterplot(data=data_suv, x='odo_per_year', y='price')
# Out:
# <AxesSubplot:xlabel='odo_per_year', ylabel='price'>

# %% [markdown]
# Berdasarkan diagram di atas, rata-rata jarak tempuh mobil SUV tidak berpengaruh terhadap harga. Walaupun rata-rata jarak tempuhnya naik, harganya tidak naik.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **-Korelasi Antara Harga dengan Kondisi Mobil**

# %%
data_suv['condition'].value_counts()
# Out:
# excellent    5063
# good         3234
# like new      864
# fair          179
# new            14
# salvage        10
# Name: condition, dtype: int64

# %%
# Data yang di bawah 50 tidak dihitung
# Data new dan salvage tidak dihitung
up4_condition = list(data_suv['condition'].value_counts()[:-2].index)
up4_condition
# Out:
# ['excellent', 'good', 'like new', 'fair']

# %%
up4_condition_suv = data_suv[data_suv['condition'].isin(up4_condition)].reset_index(drop=True)

# %%
# Diagram korelasi antara harga dengan kondisi mobil
sns.boxplot(data=up4_condition_suv, x='condition', y='price')
plt.title('Correlation between Price and Condition')
# Out:
# Text(0.5, 1.0, 'Correlation between Price and Condition')

# %% [markdown]
# 1. Dari diagram boxplot diatas, dapat kita ketahui bahwa kisaran harga mobil SUV dengan kondisi 'like new' paling tinggi dibandingkan dengan kondisi yang lain dengan batas atas harganya mencapai 30000.
# 2. Harga mobil SUV paling rendah adalah harga mobil dengan kondisi 'fair' (sedang) dengan batas atas harganya mencapai 6000.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **-Korelasi Antara Harga dengan TypeTransmisi Mobil**

# %%
data_suv['transmission'].value_counts()
# Out:
# automatic    8891
# manual        354
# other         119
# Name: transmission, dtype: int64

# %%
# Diagram korelasi antara harga dengan transmisi mobil
sns.boxplot(data=data_suv, x='transmission', y='price')
plt.title('Correlation between Price and Transmission')
# Out:
# Text(0.5, 1.0, 'Correlation between Price and Transmission')

# %% [markdown]
# 1. Dari diagram boxplot di atas dapat kita ketahui bahwa untuk mobil SUV, tipe transmisi tidak terlalu berpengaruh ke harga. Harga antara tipe automatic, manual, dan other hampir sama yakni dengan batas atas harga mencapai 30000.
# 2. Harga Rata-rata mobil SUV tipe manual lebih tinggi dibandingkan tipe yang lain yakni mencapai 11000.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# **-Korelasi Antara Harga dengan Warna Mobil**

# %%
data_suv['paint_color'].value_counts()
# Out:
# unknown    1684
# black      1630
# white      1436
# silver     1257
# grey        905
# blue        816
# red         676
# green       296
# brown       295
# custom      235
# orange       67
# yellow       35
# purple       32
# Name: paint_color, dtype: int64

# %%
# Data yang di bawah 50 tidak dihitung
# Data yellow dan purple tidak dihitung
up11_color = list(data_suv['paint_color'].value_counts()[:-2].index)
up11_color
# Out:
# ['unknown',
#  'black',
#  'white',
#  'silver',
#  'grey',
#  'blue',
#  'red',
#  'green',
#  'brown',
#  'custom',
#  'orange']

# %%
up11_color_suv = data_suv[data_suv['paint_color'].isin(up11_color)].reset_index(drop=True)

# %%
# Diagram korelasi antara harga dengan warna mobil
sns.boxplot(data=up11_color_suv, x='paint_color', y='price')
plt.title('Correlation between Price and Color')
plt.figure(figsize=(12,6))

# %% [markdown]
# 1. Dari diagram boxplot di atas dapat kita ketahui bahwa mobil SUV dengan warna 'black' (hitam) memiliki kisaran harga paling tinggi dengan batas atas harganya mencapai 33000.
# 2. Mobil sedan dengan kisaran harga paling rendah adalah mobil berwarna 'blue' (biru) dengan batas atas harganya mencapai 180000.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Kesimpulan Umum
# [Tulis kesimpulan pentingmu di bagian akhir ini. Pastikan bahwa kesimpulanmu mencakup penjelasan tentang caramu memproses dan menganalisis data. Laporkan nilai yang hilang, duplikat, outlier, serta alasan dan solusi untuk permasalahan yang harus kamu tangani. Sekali lagi, jangan lupa untuk menghapus semua komentar dalam tanda kurung sebelum mengirimkan proyekmu, ya.]

# %% [markdown]
# **KESIMPULAN UMUM**
#
# 1. Dari informasi umum terdapat 51.525 baris dan 13 kolom.
# 2. Terdapat 5 kolom yang mengandung nilai yang hilang yakni:model_year, cylinders, odometer, paint_color, dan is_4wd. Kolom is_4wd mengandung nilai hilang paling banyak yakni sebanyak 50.36 %.
# 3. Ada kolom dengan tipe data yang tidak sesuai yaitu kolom model_year, is_4wd, dan date_posted. Kolom model_year harusnya tipe integer, kolom is_4wd harusnya integer, dan kolom date_posted harusnya tipe date.
# 4. Nilai hilang di kolom is_4wd diganti dengan 0. Nilai hilang di kolom paint_color diganti dengan 'unknown'. Nilai hilang di kolom odometer, cylinders, dan model_year diganti dengan nilai median.
# 5. Type data di kolom model_year dan is_4wd diubah dari float menjadi integer. Sedangkan kolom date_posted diubah dari string menjadi datetime.
# 6. Agar maksudnya lebih jelas, maka nilai di dalam kolom is_4wd diubah, 1 menjadi Yes dan 0 menjadi No.
# 7. Temuan data (findings) berdasarkan diagram kolom price:
#     - Harga mobil tersebar pada range harga 0 - 50000
#     - Ada data outlier yang mencapai 350000
#     - Rata-rata harga mobil adalah 12132,46
#     - 50 % mobil dijual dibawah harga 9000
# 8. Temuan data (findings) berdasarkan diagram kolom car_age:
#     - Usia mobil pada saat iklan ditayangkan tersebar pada range usia 0 - 20 tahun
#     - Ada data outlier usia mobil mencapai 110 tahun
#     - Rata-rata usia mobil adalah 8,5 tahun
# 9. Temuan data (findings) berdasarkan diagram kolom odo_per_year:
#     - Nilai rata-rata jarak tempuh mobil per tahun pada saat iklan ditayangkan tersebar pada range 0 - 50000 km/tahun
#     - Ada data outlier odo per year mobil mencapai 373200 km/tahun
#     - Rata-rata odo_per_year mobil adalah 15378.48 km/tahun
#     - 50% odometer mobil masih di bawah 13036.18 km/tahun
# 10. Temuan data (findings) berdasarkan diagram kolom cylinders:
#     - Mobil yang paling banyak diiklankan adalah mobil dengan jumlah cylinder 8, 6, dan 4 (mencapai 97 %)
#     - 3 % sisanya adalah mobil dengan jumlah cylinder 3,5,10, dan 12.
#     - Dari diagram boxplot, jumlah mobil yang diiklankan tersebar diantara 3 jenis cylinder yakni 4, 6, dan 8.
# 11. Temuan data (findings) berdasarkan diagram kolom condition:
#     - Mobil yang paling banyak diiklankan adalah mobil dengan kondisi excellent yakni sebanyak 48,07 % dan mobil dengan kondisi good sebanyak 39,09 %.
#     - Mobil baru (new) dan rongsokan (salvage) sangat sedikit diiklankan, hanya sebanyak 0,2 %.
#     - Dari diagram boxplot, kondisi 1 (fair) adalah batas bawah outlier jadi minimal kondisi mobil yang akan diiklankan adalah mobil dengan kondisi fair (sedang). Sedangkan kondisi 4 (like new) adalah batas atas outlier kondisi mobil yang akan diiklankan.
#     - Untuk mobil new (baru) biasanya dijual langsung di dealer.
# 12. Kolom yang memiliki nilai outlier adalah kolom price, car_age, dan odo_per_year. Nilai batas atas outlier kolom price adalah 29597.5. Nilai batas atas outlier kolom car_age adalah 17.5. Dan nilai batas atas outlier kolom odo_per_year adalah 21279.68. Dan selanjutnya data outlier dihilangkan.
# 13. Temuan data dari diagram price tanpa outlier:
#     - Rata-rata harga mobil turun dari 12132.46 menjadi 10448.94
#     - 50% mobil dijual di bawah harga 8500
#     - Harga mobil tertinggi adalah 29588
# 14. Temuan data dari diagram car_age tanpa outlier:
#     - Rata-rata usia mobil turun dari 9.51 tahun menjadi 9.42 tahun
#     - 50% usia mobil yang diiklankan di bawah 9 tahun
#     - Usia mobil tertinggi adalah 17 tahun
# 15. Temuan data dari diagram odo_per_year tanpa outlier:
#     - Rata-rata jarak tempuh mobil yang diiklankan turun dari 15378.48 km/tahun menjadi 12361.19 km/tahun
#     - 50% jarak tempuh mobil yang diiklankan berada di bawah 12420.81 km/tahun
#     - Jarak tempuh mobil tertinggi adalah 21278 km/tahun
# 16. Berdasarkan temuan dalam diagram kolom days_listed:
#     - Rata-rata iklan ditayangkan selama 39.6 hari.
#     - Paling cepat iklan mobil ditayangkan kurang dari sehari. Artinya mobil tersebut terjual di hari yang sama ketika iklan mobil itu ditayangkan.
#     - Iklan mobil yang paling lama ditayangkan adalah selama 271 hari (9 bulanan).
#     - Nilai batas outier adalah 100 hari artinya iklan mobil dikatakan sangat lama jika sudah ditayangkan lebih dari 100 hari.
# 17. Temuan data berdasarkan type mobil
#     - Type mobil yang paling banyak diiklankan adalah type Sedan dan SUV.
#     - Type mobil yang paling sedikit diiklankan adalah type Offroad dan Bus.
#     - Rata-rata harga mobil SUV lebih tinggi daripada rata-rata harga mobil Sedan.
# 18. Faktor-faktor yang mempengaruhi harga: Berdasarkan diagram scatterplot dan boxplot, Faktor-faktor yang mempengaruhi harga mobil Sedan dan SUV antara lain:
#     - Berdasarkan diagram korelasi antara harga dengan usia mobil, mobil yang usianya rendah, harganya lebih tinggi. Semakin bertambah usia mobil, harganya semakin turun.
#     - Berdasarkan diagram korelasi antara harga dengan rata-rata jarak tempuh, korelasinya sangat kecil, hampir tidak ada pengaruh. Walapun rata-rata jerak tempuh mobil naik, tapai harga
#     - Berdasarkan diagram korelasi antara harga dengan kondisi, mobil dengan kondisi like_new memiliki harga yang paling tinggi dibandingkan kondisi lainnya.
#     - Berdasarkan diagram korelasi antara harga dengan tipe transmisi, untuk mobil Sedan, tipe automatic memiliki harga yang lebih tinggi dibandingkan tipe manual. Namun untuk mobil SUV, tipe transmisi tidak terlalu berpengaruh ke harga, karena harga mobil SUV tipe automatic dan tipe manual tidak terlalu berbeda.
#     - Berdasarkan diagram korelasi antara harga dengan warna mobil, mobil berwarna black (hitam) memiliki harga paling tinggi dibandingkan warna lainnya.

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>
